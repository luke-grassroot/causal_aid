# %%
import pandas as pd

# %%
aid_data = pd.read_csv('../data/aiddata/AidDataCoreDonorRecipientYearPurpose_ResearchRelease_Level1_v3.1.csv')

# %%
aid_data.head()
# Out:
#                                          donor  \
# 0  African Capacity Building Foundation (ACBF)
# 1  African Capacity Building Foundation (ACBF)
# 2  African Capacity Building Foundation (ACBF)
# 3  African Capacity Building Foundation (ACBF)
# 4  African Capacity Building Foundation (ACBF)
#
#                                       recipient  year  coalesced_purpose_code  \
# 0  Africa, Regional Programs, Regional Programs  2000                 11420.0
# 1  Africa, Regional Programs, Regional Programs  2001                 16020.0
# 2  Africa, Regional Programs, Regional Programs  2004                 15110.0
# 3  Africa, Regional Programs, Regional Programs  2004                 60010.0
# 4  Africa, Regional Programs, Regional Programs  2005                 11420.0
#
#                             coalesced_purpose_name  \
# 0                                 Higher education
# 1  Employment policy and administrative management
# 2         Economic and development policy/planning
# ...

# %%
print(aid_data.donor.value_counts().to_dict())
# Out:
# {'United States': 56631, 'Germany': 51193, 'France': 50875, 'Spain': 38655, 'Canada': 35829, 'Norway': 31935, 'Japan': 31220, 'United Kingdom': 29545, 'United Nations Children`s Fund (UNICEF)': 29254, 'Belgium': 28236, 'Netherlands': 25669, 'Italy': 24853, 'Sweden': 24513, 'European Communities (EC)': 24448, 'Australia': 23917, 'Switzerland': 20483, 'United Nations Development Programme (UNDP)': 14802, 'Korea': 14577, 'Finland': 13015, 'Austria': 12068, 'Ireland': 11018, 'Denmark': 8339, 'World Bank - International Development Association (IDA)': 6903, 'Portugal': 6695, 'Asian Development Bank (ASDB)': 6608, 'Luxembourg': 6274, 'New Zealand': 6088, 'World Bank - International Bank for Reconstruction and Development (IBRD)': 6018, 'United Nations Population Fund (UNFPA)': 5836, 'Inter-American Development Bank (IADB)': 5418, 'Greece': 5348, 'Global Environment Facility (GEF)': 2947, 'World Health Organization (WHO)': 2832, 'World Bank - International Finance Corporation (IFC)': 2623, 
# ...

# %%
honig = pd.read_csv('../data/aid_projects.csv')
# Out:
# /home/luke/miniconda3/envs/causal/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (11,12,13,15,16,18,20,22,23,24,25,26,27,28,29,32,33,35,36,37,38,40,42,43,44,45,46,88,93,94,95,96,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,114,115,119,120,121,122,123,124,125,129,132,133,134,150,151,152,153,154,155,181,182,183) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
honig.head()
# Out:
#    ppd_project_id donor_name  six_overall_rating country_code  \
# 0               1    AsianDB                 4.5          CHN
# 1               2    AsianDB                 4.5          COO
# 2               3    AsianDB                 1.5          PHI
# 3               4    AsianDB                 4.5          NEP
# 4               5    AsianDB                 4.5          SRI
#
#    office_presence  project_duration  eval_lag  crs_purpose_code  \
# 0              1.0            2555.0     730.0               NaN
# 1              0.0            1825.0       0.0           22040.0
# 2              1.0            2190.0     730.0               NaN
# 3              1.0            6570.0    1095.0           21050.0
# 4              1.0            1825.0       0.0           24010.0
#
#    crs_purpose_sector aid_type  ... kfw_sustainability_rating  \
# 0                 NaN      NaN  ...                       NaN
# 1               220.0        L  ...                       NaN
# ...

# %%
honig.donor_name.value_counts()
# Out:
# WB         7146
# KfW        2229
# DFID       1917
# AsianDB    1572
# JICA        723
# GFATM       581
# GiZ         129
# IFAD         55
# Name: donor_name, dtype: int64

# %%
# okay code the above for "is in"
# then sum the amounts from 1990 onwards
